# %%
#importing libraries 
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
from scipy.stats import skew, norm
from scipy.special import boxcox1p
from scipy.stats import boxcox_normmax
from sklearn.model_selection import KFold, cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

# %%
#load the data
training = pd.read_csv('/content/train.csv')
test = pd.read_csv('/content/test.csv')

# %%
# print the fist 10 rows of the data 
training.head(10)
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
# 5   6          50       RL  ...        WD         Normal    143000
# 6   7          20       RL  ...        WD         Normal    307000
# 7   8          60       RL  ...        WD         Normal    200000
# 8   9          50       RM  ...        WD        Abnorml    129900
# 9  10         190       RL  ...        WD         Normal    118000
#
# [10 rows x 81 columns]

# %%
#count the no of rows and columns in the dataset 
training.shape , test.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
training.corr()
# Out:
#                      Id  MSSubClass  LotFrontage  ...    MoSold    YrSold  SalePrice
# Id             1.000000    0.011156    -0.010601  ...  0.021172  0.000712  -0.021917
# MSSubClass     0.011156    1.000000    -0.386347  ... -0.013585 -0.021407  -0.084284
# LotFrontage   -0.010601   -0.386347     1.000000  ...  0.011200  0.007450   0.351799
# LotArea       -0.033226   -0.139781     0.426095  ...  0.001205 -0.014261   0.263843
# OverallQual   -0.028365    0.032628     0.251646  ...  0.070815 -0.027347   0.790982
# OverallCond    0.012609   -0.059316    -0.059213  ... -0.003511  0.043950  -0.077856
# YearBuilt     -0.012713    0.027850     0.123349  ...  0.012398 -0.013618   0.522897
# YearRemodAdd  -0.021998    0.040581     0.088866  ...  0.021490  0.035743   0.507101
# MasVnrArea    -0.050298    0.022936     0.193458  ... -0.005965 -0.008201   0.477493
# BsmtFinSF1    -0.005024   -0.069836     0.233633  ... -0.015727  0.014359   0.386420
# BsmtFinSF2    -0.005968   -0.065649     0.049900  ... -0.015211  0.031706  -0.011378
# BsmtUnfSF     -0.007940   -0.140759     0.132644  ...  0.034888 -0.041258   0.214479
# TotalBsmtSF   -0.015415   -0.238518     0.392075  ...  0.013196 -0.014969   0.613581
# 1stFlrSF       0.010496   -0.251758     0.457181  ...  0.031372 -0.013604   0.605852
# 2ndFlrSF       0.005590    0.307886     0.080177  ...  0.035164 -0.028700   0.319334
# LowQualFinSF  -0.044230    0.046474     0.038469  ... -0.022174 -0.028921  -0.025606
# GrLivArea      0.008273    0.074853     0.402797  ...  0.050240 -0.036526   0.708624
# BsmtFullBath   0.002289    0.003491     0.100949  ... -0.025361  0.067049   0.227122
# BsmtHalfBath  -0.020155   -0.002333    -0.007234  ...  0.032873 -0.046524  -0.016844
# FullBath       0.005587    0.131608     0.198769  ...  0.055872 -0.019669   0.560664
# HalfBath       0.006784    0.177354     0.053532  ... -0.009050 -0.010269   0.284108
# BedroomAbvGr   0.037719   -0.023438     0.263170  ...  0.046544 -0.036014   0.168213
# KitchenAbvGr   0.002951    0.281721    -0.006069  ...  0.026589  0.031687  -0.135907
# TotRmsAbvGrd   0.027239    0.040380     0.352096  ...  0.036907 -0.034516   0.533723
# Fireplaces    -0.019772   -0.045569     0.266639  ...  0.046357 -0.024096   0.466929
# GarageYrBlt    0.000072    0.085072     0.070250  ...  0.005337 -0.001014   0.486362
# GarageCars     0.016570   -0.040110     0.285691  ...  0.040522 -0.039117   0.640409
# GarageArea     0.017634   -0.098672     0.344997  ...  0.027974 -0.027378   0.623431
# WoodDeckSF    -0.029643   -0.012579     0.088521  ...  0.021011  0.022270   0.324413
# OpenPorchSF   -0.000477   -0.006100     0.151972  ...  0.071255 -0.057619   0.315856
# EnclosedPorch  0.002889   -0.012037     0.010700  ... -0.028887 -0.009916  -0.128578
# 3SsnPorch     -0.046635   -0.043825     0.070029  ...  0.029474  0.018645   0.044584
# ScreenPorch    0.001330   -0.026030     0.041383  ...  0.023217  0.010694   0.111447
# PoolArea       0.057044    0.008283     0.206167  ... -0.033737 -0.059689   0.092404
# MiscVal       -0.006242   -0.007683     0.003368  ... -0.006495  0.004906  -0.021190
# MoSold         0.021172   -0.013585     0.011200  ...  1.000000 -0.145721   0.046432
# YrSold         0.000712   -0.021407     0.007450  ... -0.145721  1.000000  -0.028923
# SalePrice     -0.021917   -0.084284     0.351799  ...  0.046432 -0.028923   1.000000
#
# [38 rows x 38 columns]

# %%
corr_matrix = training.corr()
corr_matrix["SalePrice"].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %% [markdown]
# almost all feature has good impact on output .

# %%
corr = training.corr()
plt.subplots(figsize=(15,12))
sns.heatmap(corr, vmax=0.9, cmap="Blues", square=True)

# %%
training.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
#count the empty values in each column
training.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
## Fill Missing Values

training['LotFrontage']=training['LotFrontage'].fillna(training['LotFrontage'].mean())

# %% [markdown]
# filling missing values with mean, as this column contains numerical values

# %%
training.drop(['Alley'],axis=1,inplace=True)

# %% [markdown]
# dropping this column as its contains a lot of null values, more than 50% values are null

# %%
training['BsmtCond']=training['BsmtCond'].fillna(training['BsmtCond'].mode()[0])
training['BsmtQual']=training['BsmtQual'].fillna(training['BsmtQual'].mode()[0])

# %% [markdown]
# as its a categorical type data , so replacing with the mode value

# %%
training['FireplaceQu']=training['FireplaceQu'].fillna(training['FireplaceQu'].mode()[0])
training['GarageType']=training['GarageType'].fillna(training['GarageType'].mode()[0])

# %% [markdown]
# again, categorical value replacing with mode value

# %%
training.drop(['GarageYrBlt'],axis=1,inplace=True)

# %% [markdown]
# more than 50% missing value , so dropped

# %%
training['GarageFinish']=training['GarageFinish'].fillna(training['GarageFinish'].mode()[0])
training['GarageQual']=training['GarageQual'].fillna(training['GarageQual'].mode()[0])
training['GarageCond']=training['GarageCond'].fillna(training['GarageCond'].mode()[0])

# %% [markdown]
# again , categorical value replacing with mode value

# %%
training.drop(['PoolQC','Fence','MiscFeature'],axis=1,inplace=True)

# %%
training.shape
# Out:
# (1460, 76)

# %%
training.drop(['Id'],axis=1,inplace=True)

# %%
training['MasVnrType']=training['MasVnrType'].fillna(training['MasVnrType'].mode()[0])
training['MasVnrArea']=training['MasVnrArea'].fillna(training['MasVnrArea'].mode()[0])

# %%
training['BsmtExposure']=training['BsmtExposure'].fillna(training['BsmtExposure'].mode()[0])

# %%
training['BsmtFinType2']=training['BsmtFinType2'].fillna(training['BsmtFinType2'].mode()[0])

# %%
sns.heatmap(training.isnull(),yticklabels=False,cbar=False,cmap='YlGnBu')

# %% [markdown]
# check if any null value exist or not .

# %%
training.dropna(inplace=True)

# %%
training.shape
# Out:
# (1422, 75)

# %%
#look at the datatypes
training.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 75, dtype: object

# %%
##HAndle Categorical Features
columns=['MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood',
         'Condition2','BldgType','Condition1','HouseStyle','SaleType',
        'SaleCondition','ExterCond',
         'ExterQual','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2',
        'RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','Heating','HeatingQC',
         'CentralAir',
         'Electrical','KitchenQual','Functional',
         'FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive']

# %%
len(columns)
# Out:
# 39

# %%
def category_onehot_multcols(multcolumns):
    df_final=final_df
    i=0
    for fields in multcolumns:
        
        print(fields)
        df1=pd.get_dummies(final_df[fields],drop_first=True)
        
        final_df.drop([fields],axis=1,inplace=True)
        if i==0:
            df_final=df1.copy()
        else:
            
            df_final=pd.concat([df_final,df1],axis=1)
        i=i+1
       
        
    df_final=pd.concat([final_df,df_final],axis=1)
        
    return df_final

# %%
main_df=training.copy()

# %%
## Combine Test Data 

test_df=pd.read_csv('Meem_newtest.csv')

# %%
test_df.shape
# Out:
# (1459, 74)

# %%
test_df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0          20       RH         80.0  ...    2010       WD        Normal
# 1          20       RL         81.0  ...    2010       WD        Normal
# 2          60       RL         74.0  ...    2010       WD        Normal
# 3          60       RL         78.0  ...    2010       WD        Normal
# 4         120       RL         43.0  ...    2010       WD        Normal
#
# [5 rows x 74 columns]

# %%
final_df=pd.concat([training,test_df],axis=0)

# %%
final_df['SalePrice']
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 1454         NaN
# 1455         NaN
# 1456         NaN
# 1457         NaN
# 1458         NaN
# Name: SalePrice, Length: 2881, dtype: float64

# %%
final_df.shape
# Out:
# (2881, 75)

# %%
final_df=category_onehot_multcols(columns)
# Out:
# MSZoning
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition2
# BldgType
# Condition1
# HouseStyle
# SaleType
# SaleCondition
# ExterCond
# ExterQual
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive

# %%
final_df.shape
# Out:
# (2881, 235)

# %%
final_df =final_df.loc[:,~final_df.columns.duplicated()]

# %%
final_df.shape
# Out:
# (2881, 175)

# %%
final_df
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  ...  CarPort  Detchd  RFn  P
# 0             60         65.0     8450            7  ...        0       0    1  0
# 1             20         80.0     9600            6  ...        0       0    1  0
# 2             60         68.0    11250            7  ...        0       0    1  0
# 3             70         60.0     9550            7  ...        0       1    0  0
# 4             60         84.0    14260            8  ...        0       0    1  0
# ...          ...          ...      ...          ...  ...      ...     ...  ... ..
# 1454         160         21.0     1936            4  ...        0       0    0  0
# 1455         160         21.0     1894            4  ...        1       0    0  0
# 1456          20        160.0    20000            5  ...        0       1    0  0
# 1457          85         62.0    10441            5  ...        0       0    0  0
# 1458          60         74.0     9627            7  ...        0       0    0  0
#
# [2881 rows x 175 columns]

# %%
df_Train=final_df.iloc[:1422,:]
df_Test=final_df.iloc[1422:,:]

# %%
#feature scalling
from sklearn.pipeline import Pipeline
from sklearn.linear_model import HuberRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import TransformedTargetRegressor
from sklearn.feature_selection import RFE

# %%
df_Train.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  ...  CarPort  Detchd  RFn  P
# 0          60         65.0     8450            7  ...        0       0    1  0
# 1          20         80.0     9600            6  ...        0       0    1  0
# 2          60         68.0    11250            7  ...        0       0    1  0
# 3          70         60.0     9550            7  ...        0       1    0  0
# 4          60         84.0    14260            8  ...        0       0    1  0
#
# [5 rows x 175 columns]

# %%
df_Train.shape
# Out:
# (1422, 175)

# %%
df_Test.shape
# Out:
# (1459, 175)

# %%
df_Test.drop(['SalePrice'],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
X_train=df_Train.drop(['SalePrice'],axis=1)
y_train=df_Train['SalePrice']

# %%
X_train.shape
# Out:
# (1422, 174)

# %%
y_train.shape
# Out:
# (1422,)

# %%
df_Test.shape
# Out:
# (1459, 174)

# %%
df_Test.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  ...  CarPort  Detchd  RFn  P
# 0          20         80.0    11622            5  ...        0       0    0  0
# 1          20         81.0    14267            6  ...        0       0    0  0
# 2          60         74.0    13830            5  ...        0       0    0  0
# 3          60         78.0     9978            6  ...        0       0    0  0
# 4         120         43.0     5005            8  ...        0       0    1  0
#
# [5 rows x 174 columns]

# %%
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn import preprocessing

# %%
# with feature scalling 
LR = linear_model.LinearRegression()
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_transformed = scaler.transform(X_train)
clf = LR.fit(X_train_transformed, y_train)
cv = cross_val_score(clf,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# [-0.00521612  0.82371562  0.80302171  0.86300256  0.63146616]
# 0.6231979855651641

# %%
#without feature scalling 
LR = linear_model.LinearRegression()

clf = LR.fit(X_train, y_train)

#y_pred=clf.predict(df_Test)

#pred = y_pred.mean()

cv = cross_val_score(clf, X_train,y_train ,cv=5)
print(cv)
print(cv.mean())
# Out:
# [-0.00521612  0.82371562  0.80302171  0.86300256  0.63146616]
# 0.6231979855651641

# %% [markdown]
# as we didnt get any difference using feature scalling , we better omit this step

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=1, solver="cholesky")
RG = ridge_reg.fit(X_train,y_train)
cv = cross_val_score(RG,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# [0.88497807 0.82299225 0.85029066 0.84590409 0.65440316]
# 0.8117136468024772

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.1)
LR = lasso_reg.fit(X_train,y_train)
cv = cross_val_score(LR,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 322971157399.4881, tolerance: 896174688.515293
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318385866166.0253, tolerance: 739072929.2097237
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 263320284845.76, tolerance: 709566307.0300968
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 197386661509.5708, tolerance: 680498933.6199715
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 247482867963.4146, tolerance: 749371095.9381504
#   positive)
# [0.00208787 0.82385076 0.80322204 0.86308309 0.63704129]
# 0.6258570112049123
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 241254750070.21265, tolerance: 705749707.639981
#   positive)

# %%
from sklearn.linear_model import ElasticNet
elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5)
EN = elastic_net.fit(X_train,y_train)
cv = cross_val_score(EN,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 709210766194.6677, tolerance: 896174688.515293
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 602663157980.1785, tolerance: 739072929.2097237
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 554169623176.8943, tolerance: 709566307.0300968
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 553100479095.6805, tolerance: 680498933.6199715
#   positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 603918410368.1619, tolerance: 749371095.9381504
#   positive)
# [0.88219937 0.82380515 0.84907063 0.85673539 0.64329574]
# 0.8110212551110587
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 439891124041.492, tolerance: 705749707.639981
#   positive)

# %%
#decision tree with max_depth 

from sklearn.tree import DecisionTreeClassifier
tree_clf = DecisionTreeClassifier(max_depth=2)
DTC = tree_clf.fit(X_train,y_train)
cv = cross_val_score(DTC,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [0.01403509 0.01052632 0.01408451 0.01408451 0.01760563]
# 0.014067210279219176

# %%
#decision tree with no restriction
from sklearn.tree import DecisionTreeClassifier
tree_clf1 = DecisionTreeClassifier()
DTC1 = tree_clf1.fit(X_train,y_train)
cv = cross_val_score(DTC1,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [0.01052632 0.01052632 0.         0.00704225 0.00352113]
# 0.006323202372127502

# %%
tree_clf1.predict(df_Test)
# Out:
# array([ 97000., 170000., 173000., ..., 153000., 145000., 335000.])

# %%
# randomforest with estimator 10  
from sklearn.ensemble import RandomForestClassifier  
classifier= RandomForestClassifier(n_estimators= 10, criterion="entropy")
RFC10= classifier.fit(X_train,y_train)  
cv = cross_val_score(RFC10,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [0.01052632 0.01754386 0.01760563 0.00704225 0.01408451]
# 0.013360513960958734

# %%
# randomforest with estimator 5 
from sklearn.ensemble import RandomForestClassifier  
classifier5= RandomForestClassifier(n_estimators= 5, criterion="entropy")
RFC5= classifier5.fit(X_train,y_train)   
cv = cross_val_score(RFC5,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [0.01052632 0.00350877 0.         0.01760563 0.00704225]
# 0.007736595008648381

# %%
# randomforest with estimator 15
from sklearn.ensemble import RandomForestClassifier  
classifier15= RandomForestClassifier(n_estimators= 15, criterion="entropy") 
RFC15= classifier15.fit(X_train,y_train)   
cv = cross_val_score(RFC15,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [0.01403509 0.01403509 0.00352113 0.00704225 0.00704225]
# 0.009135161848282678

# %%
#feature scalling 

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_data = scaler.transform(X_train)

# %%
# apply PCA on linear regression and decision tree 

from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(scaled_data)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
x_pca = pca.transform(scaled_data)

# %%
scaled_data.shape
# Out:
# (1422, 174)

# %%
x_pca.shape
# Out:
# (1422, 2)

# %%
df_Test.shape
# Out:
# (1459, 174)

# %%
LR_pca = linear_model.LinearRegression()
LRPCS = LR_pca.fit(x_pca,y_train)
cv = cross_val_score(LRPCS,x_pca,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# [0.71488268 0.70709643 0.70578407 0.7322169  0.59571792]
# 0.6911396002345997

# %%
from sklearn.tree import DecisionTreeClassifier
DT_pca = DecisionTreeClassifier(max_depth=2)
DTP = DT_pca.fit(x_pca,y_train)
cv = cross_val_score(DTP,x_pca,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# [0.0245614  0.01403509 0.01760563 0.01408451 0.01760563]
# 0.0175784531751915
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)

# %% [markdown]
# after applying pca , the performance increased a little bit

# %%
from sklearn.tree import DecisionTreeClassifier
Dt_pca = DecisionTreeClassifier()
DTPCS = Dt_pca.fit(x_pca,y_train)
cv = cross_val_score(DTPCS,x_pca,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [0.00701754 0.00701754 0.01408451 0.         0.        ]
# 0.005623918952310353
