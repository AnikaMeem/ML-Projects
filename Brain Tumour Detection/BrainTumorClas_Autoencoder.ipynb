# %% [markdown]
# # Python Library Import

# %%
import os
import glob
import numpy as np 
import pandas as pd 
import random
from os import listdir
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import imutils    

from tensorflow.keras.models import Model,load_model
from tensorflow.keras.layers import Conv2D,Input,ZeroPadding2D,BatchNormalization,Flatten,Activation,Dense,MaxPooling2D
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle 
from keras.preprocessing import image
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.layers import Input, Dense, Activation, BatchNormalization, Flatten, Conv2D
from keras.layers import MaxPooling2D, Dropout, UpSampling2D

# %% [markdown]
# # Images Directory

# %%
image_dir="./BrainTumorDatasets/"

image_dir
# Out:
# './BrainTumorDatasets/'

# %%
path = os.path.join(image_dir, 'no/')
img_loc = random.choice(os.listdir(path))
img = cv2.imread(os.path.join(path, img_loc))
print('Shape of Image:',img.shape)
# Out:
# Shape of Image: (474, 356, 3)

# %%
print('______Healthy Brain Images______')
plt.figure(figsize=(20,5))
img = cv2.imread('./BrainTumorDatasets/no/image(74).jpg', 0)
plt.imshow(img, cmap='gray')
# Out:
# ______Healthy Brain Images______

# %%
path = os.path.join(image_dir, 'yes/')
img_loc = random.choice(os.listdir(path))
img = cv2.imread(os.path.join(path, img_loc))
print('Shape of Image:',img.shape)
# Out:
# Shape of Image: (520, 433, 3)

# %%
print('______Tumor Brain Images______')
plt.figure(figsize=(20,5))
img = cv2.imread('./BrainTumorDatasets/yes/Y1.jpg', 1)
plt.imshow(img, cmap='gray')
print('Shape of Image:', img.shape)
# Out:
# ______Tumor Brain Images______
# Shape of Image: (630, 587, 3)

# %%
Yes_IMAGES = glob.glob('./BrainTumorDatasets/yes/*.jpg')
No_IMAGES = glob.glob('./BrainTumorDatasets/no/*.jpg')

# %%
def load_image(path):
    image_list = np.zeros((len(path), 224,224, 1))
    for i, fig in enumerate(path):
        img = image.load_img(fig, color_mode='grayscale', target_size=(224, 224))
        x = image.img_to_array(img).astype('float32')
        x = x / 255.0
        image_list[i] = x
    
    return image_list

# %% [markdown]
# # Splitting Images

# %%
x_train = load_image(Yes_IMAGES)
y_train = load_image(Yes_IMAGES)
x_test = load_image(No_IMAGES)
y_test = load_image(No_IMAGES)
print(x_train.shape, x_test.shape)
# Out:
# (1500, 224, 224, 1) (1895, 224, 224, 1)

# %%
def train_val_split(x_train, y_train):
    rnd = np.random.RandomState(seed=42)
    perm = rnd.permutation(len(x_train))
    train_idx = perm[:int(0.8 * len(x_train))]
    val_idx = perm[int(0.8 * len(x_train)):]
    return x_train[train_idx], y_train[train_idx], x_train[val_idx], y_train[val_idx]

x_train, y_train, x_val, y_val = train_val_split(x_train, y_train)
print(x_train.shape, x_val.shape)
# Out:
# (1200, 224, 224, 1) (300, 224, 224, 1)

# %% [markdown]
# # Training Model

# %%
class Autoencoder():
    def __init__(self):
        self.img_rows = 224
        self.img_cols = 224
        self.channels = 1
        self.img_shape = (self.img_rows, self.img_cols, self.channels)
        
        optimizer = Adam(lr=0.001)
        
        self.autoencoder_model = self.build_model()
        self.autoencoder_model.compile(loss='mse', optimizer=optimizer, metrics=["accuracy"])
        self.autoencoder_model.summary()
    
    def build_model(self):
        input_layer = Input(shape=self.img_shape)
        
        # encoder
        h = Conv2D(64, (3, 3), activation='relu', padding='same')(input_layer)
        h = MaxPooling2D((2, 2), padding='same')(h)
        
        # decoder
        h = Conv2D(64, (3, 3), activation='relu', padding='same')(h)
        h = UpSampling2D((2, 2))(h)
        output_layer = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(h)
        
        return Model(input_layer, output_layer)
    
    def train_model(self, x_train, y_train, x_val, y_val, epochs, batch_size=20):
        early_stopping = EarlyStopping(monitor='val_loss',
                                       min_delta=0,
                                       patience=5,
                                       verbose=1, 
                                       mode='auto')
        history = self.autoencoder_model.fit(x_train, y_train,
                                             batch_size=batch_size,
                                             epochs=epochs,
                                             validation_data=(x_val, y_val),
                                             callbacks=[early_stopping])
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc='upper left')
        plt.show()
        
        plt.plot(history.history["accuracy"],c = "blue")
        plt.plot(history.history["val_accuracy"],c = "green")
        plt.title("Accuracy")
        plt.ylabel("Accuracy")
        plt.xlabel("Epoch")
        plt.legend(["Train", "Test"], loc='upper right')
        plt.show()
    
    def eval_model(self, x_test):
        preds = self.autoencoder_model.predict(x_test)
        return preds

# %%
ae = Autoencoder()
ae.train_model(x_train, y_train, x_val, y_val, epochs=50, batch_size=20)
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 64)      640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 224, 224, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 224, 224, 1)       577
# =================================================================
# Total params: 38,145
# Trainable params: 38,145
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 60/60 [==============================] - 342s 6s/step - loss: 0.0434 - val_loss: 0.0111
# Epoch 2/50
# 60/60 [==============================] - 325s 5s/step - loss: 0.0087 - val_loss: 0.0073
# Epoch 3/50
# 60/60 [==============================] - 329s 5s/step - loss: 0.0068 - val_loss: 0.0061
# Epoch 4/50
# 60/60 [==============================] - 364s 6s/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 5/50
# 60/60 [==============================] - 412s 7s/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 6/50
# 60/60 [==============================] - 415s 7s/step - loss: 0.0046 - val_loss: 0.0043
# Epoch 7/50
# 60/60 [==============================] - 432s 7s/step - loss: 0.0043 - val_loss: 0.0040
# Epoch 8/50
# 60/60 [==============================] - 444s 7s/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 9/50
# 60/60 [==============================] - 408s 7s/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 10/50
# 60/60 [==============================] - 380s 6s/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 11/50
# 60/60 [==============================] - 364s 6s/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 12/50
# 60/60 [==============================] - 366s 6s/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 13/50
# 60/60 [==============================] - 290s 5s/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 14/50
# 60/60 [==============================] - 277s 5s/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 15/50
# 60/60 [==============================] - 383s 6s/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 16/50
# 60/60 [==============================] - 513s 9s/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 17/50
# 60/60 [==============================] - 431s 7s/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 18/50
# 60/60 [==============================] - 320s 5s/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 19/50
# 60/60 [==============================] - 315s 5s/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 20/50
# 60/60 [==============================] - 304s 5s/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 21/50
# 60/60 [==============================] - 304s 5s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 22/50
# 60/60 [==============================] - 306s 5s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 23/50
# 60/60 [==============================] - 6682s 111s/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 24/50
# 60/60 [==============================] - 308s 5s/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 25/50
# 60/60 [==============================] - 318s 5s/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 26/50
# 60/60 [==============================] - 317s 5s/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 27/50
# 60/60 [==============================] - 323s 5s/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 28/50
# 60/60 [==============================] - 329s 5s/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 29/50
# 60/60 [==============================] - 344s 6s/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 30/50
# 60/60 [==============================] - 341s 6s/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 31/50
# 60/60 [==============================] - 342s 6s/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 32/50
# 60/60 [==============================] - 377s 6s/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 33/50
# 60/60 [==============================] - 367s 6s/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 34/50
# 60/60 [==============================] - 367s 6s/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 35/50
# 60/60 [==============================] - 366s 6s/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 36/50
# 60/60 [==============================] - 319s 5s/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 37/50
# 60/60 [==============================] - 394s 7s/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 38/50
# 60/60 [==============================] - 384s 6s/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 39/50
# 60/60 [==============================] - 327s 5s/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 40/50
# 60/60 [==============================] - 395s 7s/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 41/50
# 60/60 [==============================] - 302s 5s/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 42/50
# 60/60 [==============================] - 301s 5s/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 43/50
# 60/60 [==============================] - 276s 5s/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 44/50
# 60/60 [==============================] - 291s 5s/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 45/50
# 60/60 [==============================] - 343s 6s/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 46/50
# 60/60 [==============================] - 324s 5s/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 47/50
# 60/60 [==============================] - 335s 6s/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 48/50
# 60/60 [==============================] - 335s 6s/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 49/50
# 60/60 [==============================] - 340s 6s/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 50/50
# 60/60 [==============================] - 329s 5s/step - loss: 0.0018 - val_loss: 0.0017

# %%
preds = ae.eval_model(x_test)

# %%
preds_0 = preds[10] * 255.0
preds_0 = preds_0.reshape(224, 224)
x_test_0 = x_test[10] * 255.0
x_test_0 = x_test_0.reshape(224, 224)
plt.imshow(x_test_0, cmap='gray')

# %%
plt.imshow(preds_0, cmap='gray')

# %%
plt.imshow(preds_0, cmap='bone')

# %%
preds = preds.reshape(-1, 224, 224)

preds
# Out:
# array([[[0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ],
#         [0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ],
#         [0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ],
#         ...,
#         [0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ],
#         [0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ],
#         [0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ]],
#
#        [[0.5       , 0.4999988 , 0.500019  , ..., 0.50002015,
#          0.5000044 , 0.5       ],
#         [0.5       , 0.5000158 , 0.5000368 , ..., 0.5000354 ,
#          0.50000507, 0.5       ],
#         [0.5       , 0.50002927, 0.50006455, ..., 0.5000126 ,
#          0.49998924, 0.5       ],
#         ...,
#         [0.5       , 0.5000128 , 0.500015  , ..., 0.5       ,
#          0.5       , 0.5       ],
#         [0.5       , 0.50001884, 0.5000222 , ..., 0.5       ,
#          0.5       , 0.5       ],
#         [0.5       , 0.50001633, 0.50002694, ..., 0.5       ,
#          0.5       , 0.5       ]],
#
#        [[0.5002704 , 0.49998778, 0.5000332 , ..., 0.50007576,
#          0.49997914, 0.50000733],
#         [0.50076306, 0.5004014 , 0.50076526, ..., 0.5004302 ,
#          0.5003365 , 0.5006912 ],
#         [0.50120175, 0.5006607 , 0.5009475 , ..., 0.500623  ,
#          0.50039613, 0.5007683 ],
#         ...,
#         [0.5010277 , 0.5005342 , 0.5010629 , ..., 0.50072485,
#          0.50062376, 0.5009751 ],
#         [0.5011618 , 0.50048256, 0.5008102 , ..., 0.5005324 ,
#          0.50057614, 0.50093615],
#         [0.50095135, 0.5005258 , 0.50067306, ..., 0.5002104 ,
#          0.5001822 , 0.50045276]],
#
#        ...,
#
#        [[0.50045073, 0.49997965, 0.5000554 , ..., 0.50012624,
#          0.49996522, 0.5000122 ],
#         [0.5012717 , 0.500669  , 0.5012754 , ..., 0.50071704,
#          0.5005609 , 0.5011519 ],
#         [0.50200295, 0.50110126, 0.5015791 , ..., 0.50103825,
#          0.50066024, 0.5012805 ],
#         ...,
#         [0.50171286, 0.50089025, 0.5017715 , ..., 0.50120807,
#          0.5010396 , 0.5016251 ],
#         [0.5019363 , 0.50080425, 0.50135034, ..., 0.50088733,
#          0.5009603 , 0.5015603 ],
#         [0.50158554, 0.50087625, 0.5011218 , ..., 0.50035065,
#          0.50030375, 0.50075465]],
#
#        [[0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ],
#         [0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ],
#         [0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ],
#         ...,
#         [0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ],
#         [0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ],
#         [0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ]],
#
#        [[0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ],
#         [0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ],
#         [0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ],
#         ...,
#         [0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ],
#         [0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ],
#         [0.5       , 0.5       , 0.5       , ..., 0.5       ,
#          0.5       , 0.5       ]]], dtype=float32)

# %%
preds_1 = preds[20] * 255.0
preds_1 = preds_1.reshape(224, 224)

plt.imshow(preds_1, cmap='PiYG')

# %%
preds_2 = preds[50] * 255.0
preds_2 = preds_2.reshape(224, 224)

plt.imshow(preds_1, cmap='twilight')

# %%
accuracyscore = ae.eval_model(y_test)
accuracyscore[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-beaca31427d9> in <module>
# ----> 1 accuracyscore = ae.eval_model(y_test)
#       2 accuracyscore[1]
#
# NameError: name 'ae' is not defined
